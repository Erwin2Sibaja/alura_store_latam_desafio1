# %% [markdown]
# <a href="https://colab.research.google.com/github/Erwin2Sibaja/alura_store_latam_desafio1/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ##**Facturación total de la tienda 1**

# %%
total_ventas_tienda = tienda['Precio'].sum()
total_ventas_tienda
# Out:
# np.float64(1150880400.0)

# %% [markdown]
# ##**Facturación total de la tienda 2**

# %%
total_ventas_tienda2 = tienda2['Precio'].sum()
total_ventas_tienda2
# Out:
# np.float64(1116343500.0)

# %% [markdown]
# ##**Facturación total de la tienda 3**

# %%
total_ventas_tienda3 = tienda3['Precio'].sum()
total_ventas_tienda3
# Out:
# np.float64(1098019600.0)

# %% [markdown]
# ##**Facturación total de la tienda 4**

# %%
total_ventas_tienda4 = tienda4['Precio'].sum()
total_ventas_tienda4
# Out:
# np.float64(1038375700.0)

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# ##**Ventas por categoría de la tienda 1**

# %%
tienda['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
top_3_categorias_tienda = tienda['Categoría del Producto'].value_counts().head(3)
display(top_3_categorias_tienda)
# Out:
# Categoría del Producto
# Muebles         465
# Electrónicos    448
# Juguetes        324
# Name: count, dtype: int64

# %% [markdown]
# ##**Ventas por categoría de la tienda 2**

# %%
tienda2['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
top_3_categorias_tienda2 = tienda2['Categoría del Producto'].value_counts().head(3)
display(top_3_categorias_tienda2)
# Out:
# Categoría del Producto
# Muebles         442
# Electrónicos    422
# Juguetes        313
# Name: count, dtype: int64

# %% [markdown]
# ##**Ventas por categoría de la tienda 3**

# %%
tienda3['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
top_3_categorias_tienda3 = tienda3['Categoría del Producto'].value_counts().head(3)
display(top_3_categorias_tienda3)
# Out:
# Categoría del Producto
# Muebles         499
# Electrónicos    451
# Juguetes        315
# Name: count, dtype: int64

# %% [markdown]
# ##**Ventas por categoría de la tienda 4**

# %%
tienda4['Categoría del Producto'].value_counts().sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
top_3_categorias_tienda4 = tienda4['Categoría del Producto'].value_counts().head(3)
display(top_3_categorias_tienda4)
# Out:
# Categoría del Producto
# Muebles         480
# Electrónicos    451
# Juguetes        338
# Name: count, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ##**Calificación promedio de los clientes de la tienda 1**

# %%
promedio_satisfaccion_cliente = tienda['Calificación'].mean()
promedio_satisfaccion_cliente
# Out:
# np.float64(3.976685036032217)

# %% [markdown]
# ##**Calificación promedio de los clientes de la tienda 2**

# %%
promedio_satisfaccion_cliente2 = tienda2['Calificación'].mean()
promedio_satisfaccion_cliente2
# Out:
# np.float64(4.037303942348453)

# %% [markdown]
# ##**Calificación promedio de los clientes de la tienda 3**

# %%
promedio_satisfaccion_cliente3 = tienda3['Calificación'].mean()
promedio_satisfaccion_cliente3
# Out:
# np.float64(4.048325561678677)

# %% [markdown]
# ##**Calificación promedio de los clientes de la tienda 4**

# %%
promedio_satisfaccion_cliente4 = tienda4['Calificación'].mean()
promedio_satisfaccion_cliente4
# Out:
# np.float64(3.9957591178965224)

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ##**Productos más y menos vendidos de la tienda 1**

# %%
producto_mas_vendido_tienda = str(tienda['Producto'].value_counts().idxmax()) + ': ' + str(tienda['Producto'].value_counts().max())
producto_mas_vendido_tienda
# Out:
# 'Microondas: 60'

# %%
producto_menos_vendido_tienda = str(tienda['Producto'].value_counts().idxmin()) + ': ' + str(tienda['Producto'].value_counts().min())
producto_menos_vendido_tienda
# Out:
# 'Auriculares con micrófono: 33'

# %% [markdown]
# ##**Productos más y menos vendidos de la tienda 2**

# %%
producto_mas_vendido_tienda2 = str(tienda2['Producto'].value_counts().idxmax()) + ': ' + str(tienda2['Producto'].value_counts().max())
producto_mas_vendido_tienda2
# Out:
# 'Iniciando en programación: 65'

# %%
producto_menos_vendido_tienda2 = str(tienda2['Producto'].value_counts().idxmin()) + ': ' + str(tienda2['Producto'].value_counts().min())
producto_menos_vendido_tienda2
# Out:
# 'Juego de mesa: 32'

# %% [markdown]
# ##**Productos más y menos vendidos de la tienda 3**

# %%
producto_mas_vendido_tienda3 = str(tienda3['Producto'].value_counts().idxmax()) + ': ' + str(tienda3['Producto'].value_counts().max())
producto_mas_vendido_tienda3
# Out:
# 'Kit de bancas: 57'

# %%
producto_menos_vendido_tienda3 = str(tienda3['Producto'].value_counts().idxmin()) + ': ' + str(tienda3['Producto'].value_counts().min())
producto_menos_vendido_tienda3
# Out:
# 'Bloques de construcción: 35'

# %% [markdown]
# ##**Productos más y menos vendidos de la tienda 4**

# %%
producto_mas_vendido_tienda4 = str(tienda4['Producto'].value_counts().idxmax()) + ': ' + str(tienda4['Producto'].value_counts().max())
producto_mas_vendido_tienda4
# Out:
# 'Cama box: 62'

# %%
producto_menos_vendido_tienda4 = str(tienda4['Producto'].value_counts().idxmin()) + ': ' + str(tienda4['Producto'].value_counts().min())
producto_menos_vendido_tienda4
# Out:
# 'Guitarra eléctrica: 33'

# %% [markdown]
# #**Costo de envío promedio por tienda**

# %% [markdown]
# ##**Costo de envio tienda 1**

# %%
costo_de_envio = tienda['Costo de envío'].mean()
costo_de_envio
# Out:
# np.float64(26018.60958033065)

# %% [markdown]
# ##**Costo de envio tienda 2**

# %%
costo_de_envio2 = tienda2['Costo de envío'].mean()
costo_de_envio
# Out:
# np.float64(26018.60958033065)

# %% [markdown]
# ##**Costo de envio tienda 3**

# %%
costo_de_envio3 = tienda3['Costo de envío'].mean()
costo_de_envio
# Out:
# np.float64(26018.60958033065)

# %% [markdown]
# ##**Costo de envio tienda 4**

# %%
costo_de_envio4 = tienda4['Costo de envío'].mean()
costo_de_envio
# Out:
# np.float64(26018.60958033065)

# %% [markdown]
# #**Resultados generales de las 4 tiendas**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from matplotlib import colormaps
from matplotlib.cm import ScalarMappable

# %% [markdown]
# ##**Resultados de ventas por tienda**

# %%
tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ventas = [total_ventas_tienda, total_ventas_tienda2, total_ventas_tienda3, total_ventas_tienda4]

fig, ax = plt.subplots(figsize=(10, 6))

ax.pie(x=ventas, labels=tiendas, autopct='%1.1f%%', startangle=90, explode=(0,0,0,0.1))

ax.set_title('Distribución de ventas por tienda',
            fontsize=16, fontweight='bold')

ax.axis('equal')

plt.show()

# %% [markdown]
# ##**Resultados ventas de productos por categoría**

# %% [markdown]
# ###**Combinar datos de top categoria de ventas**

# %%
top_categorias_dict = {
    'Tienda 1': top_3_categorias_tienda,
    'Tienda 2': top_3_categorias_tienda2,
    'Tienda 3': top_3_categorias_tienda3,
    'Tienda 4': top_3_categorias_tienda4
}

top_categorias_df = pd.DataFrame(top_categorias_dict)
top_categorias_df.index.name = 'Categoría'
top_categorias_df
# Out:
#               Tienda 1  Tienda 2  Tienda 3  Tienda 4
# Categoría
# Muebles            465       442       499       480
# Electrónicos       448       422       451       451
# Juguetes           324       313       315       338

# %%
fig, ax = plt.subplots(figsize=(12, 8))
categorias = top_categorias_df.index
bar_width = 0.15

rango = np.arange(len(categorias))

for i in range(len(tiendas)):
    ax.bar(rango + i * bar_width, top_categorias_df[tiendas[i]], width=bar_width, label=tiendas[i])

ax.set_xlabel('Categoría')
ax.set_ylabel('Ventas')
ax.set_title('Comparativa de Ventas de las 3 Categorías Principales por Tienda', fontsize=16, fontweight='bold')
ax.set_xticks(rango + bar_width)
ax.set_xticklabels(categorias)
ax.legend()

plt.show()

# %%
productos_ventas = {
    'Tienda 1': {'Más vendido': producto_mas_vendido_tienda, 'Menos vendido': producto_menos_vendido_tienda},
    'Tienda 2': {'Más vendido': producto_mas_vendido_tienda2, 'Menos vendido': producto_menos_vendido_tienda2},
    'Tienda 3': {'Más vendido': producto_mas_vendido_tienda3, 'Menos vendido': producto_menos_vendido_tienda3},
    'Tienda 4': {'Más vendido': producto_mas_vendido_tienda4, 'Menos vendido': producto_menos_vendido_tienda4}
}

unidades_mas_vendido = []
for tienda in tiendas:
    producto_str = productos_ventas[tienda]['Más vendido']
    unidades = int(producto_str.split(': ')[1])
    unidades_mas_vendido.append(unidades)

df_plot = top_categorias_df.T.copy()

df_plot['P. más vendido'] = unidades_mas_vendido

df_plot_T = df_plot.T
metrics = df_plot_T.index

fig, ax = plt.subplots(figsize=(14, 8))
bar_width = 0.15
rango = np.arange(len(tiendas))

colores_metrics = plt.cm.Set1.colors[:len(metrics)]

for i, metric in enumerate(metrics):
    ax.bar(
        rango + i * bar_width,
        df_plot_T.loc[metric],
        width=bar_width,
        label=metric,
        color=colores_metrics[i],
        alpha=0.8
    )

ax.set_title('Comparativa de Unidades Vendidas (Categorías vs. Producto más vendido)', fontsize=16, fontweight='bold')
ax.set_xlabel('Tienda', fontsize=12)
ax.set_ylabel('Unidades Vendidas', fontsize=12)

ax.set_xticks(rango + (len(metrics)/2 - 0.5) * bar_width)
ax.set_xticklabels(tiendas)

ax.grid(axis='y', linestyle='--', alpha=0.6)
ax.legend(title='Categorías')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##**Ventas, Calificaciones y gastos**

# %%
dict_datos_general = pd.DataFrame({
    'Tienda': list(tiendas),
    'Ventas': [total_ventas_tienda, total_ventas_tienda2, total_ventas_tienda3, total_ventas_tienda4],
    'Calificaciones': [promedio_satisfaccion_cliente, promedio_satisfaccion_cliente2, promedio_satisfaccion_cliente3, promedio_satisfaccion_cliente4],
    'Costo de envío promedio': [costo_de_envio, costo_de_envio2, costo_de_envio3, costo_de_envio4]
    })

# %%
df_analisis = pd.DataFrame(dict_datos_general)
df_analisis.head()
# Out:
#      Tienda        Ventas  Calificaciones  Costo de envío promedio
# 0  Tienda 1  1.150880e+09        3.976685             26018.609580
# 1  Tienda 2  1.116344e+09        4.037304             25216.235693
# 2  Tienda 3  1.098020e+09        4.048326             24805.680373
# 3  Tienda 4  1.038376e+09        3.995759             23459.457167

# %%
scaler = MinMaxScaler()

df_resultado = df_analisis.copy()
df_resultado[['Ventas', 'Calificaciones']] = scaler.fit_transform(df_resultado[['Ventas', 'Calificaciones']])
df_resultado['Costo de envío promedio'] = 1 - scaler.fit_transform(df_resultado[['Costo de envío promedio']])

df_resultado['Índice de rendimiento'] = (
    df_resultado['Ventas'] * 0.5 +
    df_resultado['Calificaciones'] * 0.3 +
    df_resultado['Costo de envío promedio'] * 0.2
)


df_final = pd.concat([df_analisis, df_resultado['Índice de rendimiento']], axis=1)
peor_tienda = df_final.sort_values('Índice de rendimiento', ascending=True).iloc[0]

df_final['Ventas_Millones'] = df_final['Ventas'] / 1e6
peor_tienda['Ventas_Millones'] = peor_tienda['Ventas'] / 1e6
tamanos_burbuja = (df_final['Costo de envío promedio'] / df_final['Costo de envío promedio'].min()) * 500 + 500
tamanio_peor_tienda = tamanos_burbuja[df_final['Tienda'] == peor_tienda['Tienda']].iloc[0]
fig, ax = plt.subplots(figsize=(10, 6))
colormap = plt.colormaps['RdYlGn']
colores = colormap(df_final['Índice de rendimiento'])

scatter_plot = ax.scatter(
    df_final['Ventas_Millones'],
    df_final['Calificaciones'],
    s=tamanos_burbuja,
    c=colores,
)

ax.scatter(
    peor_tienda['Ventas_Millones'],
    peor_tienda['Calificaciones'],
    s=tamanio_peor_tienda,
    color='red',
)

sugerencia_final = ax.scatter(
    -100, -100,
    s=100,
    color='red',
    linewidth=1,
    label=f"La tienda con peor rendimiento es la {peor_tienda['Tienda']}"
)

for i, tienda in enumerate(df_final['Tienda']):
    ax.annotate(
        tienda,
        (df_final['Ventas_Millones'][i], df_final['Calificaciones'][i]),
        textcoords="offset points",
        xytext=(0, 0),
        ha='center',
        fontsize=9,
        fontweight='bold'
    )

ax.set_title('Analisís de rendimiento por tienda', fontsize=16, fontweight='bold')
ax.set_xlabel('Ventas Totales (Millones de $)', fontsize=12)
ax.set_ylabel('Calificación Promedio de Clientes', fontsize=12)

ax.set_xlim(df_final['Ventas_Millones'].min() - 20, df_final['Ventas_Millones'].max() + 20)
ax.set_ylim(df_final['Calificaciones'].min() - 0.05, df_final['Calificaciones'].max() + 0.05)


ax.grid(True, linestyle='--', alpha=0.7)
ax.legend(loc="lower left", frameon=True)

sm = ScalarMappable(cmap=colormap)
sm.set_array(df_final['Índice de rendimiento'])
cbar = plt.colorbar(sm, ax=ax)
cbar.set_label('Índice de Rendimiento (0-1)', rotation=270, labelpad=15)

plt.show()

# %% [markdown]
# #**Informe final de acuerdo con el analisis de los datos**

# %% [markdown]
# ##**Resumen del Análisis**
#
#
# ---
#
#
# * **Ventas y Productos**: Al comparar las ventas totales, las categorías más vendidas y el producto estrella de cada tienda, encontramos que todas las tiendas están en un nivel de ventas similar. La venta del producto más vendido de la Tienda 4 no es tan débil como para ser la única causa de sus problemas. El bajo desempeño es general.
#
#
# ---
#
#
# * **Análisis de Rendimiento**: Creamos un índice de rendimiento general que combina tres factores críticos, dándoles diferentes pesos:
#
#     1. Ventas Totales: (50% de importancia)
#     2. Calificaciones de Clientes: (30% de importancia)
#     3. Costo de Envío Promedio (Gastos): (20% de importancia)
#
#
# ---
#
#
# * **Resultados del Índice de rendimiento general**:
#
#     1. Las tiendas con mejor rendimiento general son la **Tienda 2 y la Tienda 3**.
#     2. Las tiendas **Tienda 4 y Tienda 1** son las que tienen los mayores problemas (las calificaciones y los costos de envío son los más bajos/mejores).
#     3. **Decisión Final**: Al comparar la Tienda 1 con la **Tienda 4, la Tienda 1** tiene un mejor desempeño en ventas totales, lo que le da una ventaja significativa. Por lo tanto, la Tienda 4 es la más débil al ser la que obtiene el peor puntaje compuesto entre sus ventas, la satisfacción de sus clientes y los costos que genera.
